# %% [markdown]
# <style>
# /* ── Fuentes ────────────────────────────── */
# @import url('https://fonts.googleapis.com/css2?family=Playfair+Display:wght@700&family=Source+Sans+Pro:wght@300;400;600&display=swap');
#
# body, .jp-Notebook { font-family: 'Source Sans Pro', sans-serif; background: #f7f4ee; }
#
# /* ── Banner del título ──────────────────── */
# .banner {
#     background: linear-gradient(135deg, #1a3c5e 0%, #2d6a9f 60%, #4a9fd4 100%);
#     border-radius: 14px;
#     padding: 40px 48px;
#     margin-bottom: 28px;
#     box-shadow: 0 8px 32px rgba(26,60,94,.30);
# }
# .banner h1 {
#     font-family: 'Playfair Display', Georgia, serif;
#     color: #ffffff;
#     font-size: 2.4rem;
#     margin: 0 0 8px 0;
#     letter-spacing: .5px;
#     text-shadow: 0 2px 8px rgba(0,0,0,.25);
# }
# .banner .subtitle {
#     color: #b8d9f5;
#     font-size: 1.05rem;
#     font-weight: 300;
#     letter-spacing: .8px;
#     text-transform: uppercase;
# }
# .banner .meta { color: #7fb8e0; font-size: .88rem; margin-top: 14px; }
#
# /* ── Secciones ──────────────────────────── */
# .section-header {
#     border-left: 5px solid #2d6a9f;
#     padding: 6px 0 6px 16px;
#     margin: 32px 0 14px 0;
#     font-family: 'Playfair Display', Georgia, serif;
#     font-size: 1.5rem;
#     color: #1a3c5e;
# }
# .subsection { font-size: 1.15rem; color: #2d6a9f; font-weight: 600; margin: 20px 0 8px; }
#
# /* ── Callouts / cajas de contenido ─────── */
# .callout-info {
#     background: #eaf4fb;
#     border-left: 4px solid #2d6a9f;
#     border-radius: 6px;
#     padding: 14px 18px;
#     margin: 12px 0;
#     font-size: .96rem;
#     line-height: 1.65;
# }
# .callout-warn {
#     background: #fef9ec;
#     border-left: 4px solid #e6a817;
#     border-radius: 6px;
#     padding: 14px 18px;
#     margin: 12px 0;
#     font-size: .96rem;
#     line-height: 1.65;
# }
# .callout-result {
#     background: #edfaf1;
#     border-left: 4px solid #27ae60;
#     border-radius: 6px;
#     padding: 14px 18px;
#     margin: 12px 0;
#     font-size: .96rem;
#     line-height: 1.65;
# }
#
# /* ── Referencias ────────────────────────── */
# .ref-item { margin: 6px 0; font-size: .92rem; color: #444; }
# .ref-item span { color: #2d6a9f; font-weight: 600; }
# </style>
#
# <div class='banner'>
#   <h1>📚 Análisis del Desarrollo Educativo y la Finalización Escolar Femenina</h1>
#   <p class='subtitle'>World Development Indicators · Banco Mundial · 2000 – 2022</p>
#   <p class='meta'>Indicador principal: <strong>SE.PRM.CMPT.FE.ZS</strong> — Primary completion rate, female (% of relevant age group)</p>
# </div>

# %% [markdown]
# <div class='section-header'>1. Introducción</div>
#
# ---
#
# <div class='subsection'>Justificación</div>
#
# <div class='callout-info'>
# La educación primaria constituye la base del desarrollo humano y económico de cualquier sociedad. Sin embargo, millones de niñas en todo el mundo no logran completarla, perpetuando ciclos de desigualdad de género, pobreza y exclusión social. Medir sistemáticamente la tasa de finalización escolar femenina permite a gobiernos, organismos internacionales y sociedad civil identificar brechas persistentes, priorizar recursos y evaluar el impacto de políticas públicas.
# <br><br>
# Este análisis se justifica porque: (i) la brecha de género en educación primaria sigue siendo significativa en varias regiones (UNESCO, 2021); (ii) el cierre de esa brecha se asocia con mejoras en salud materno-infantil, reducción de la pobreza y crecimiento económico sostenido (World Bank, 2023); y (iii) los datos del World Development Indicators (WDI) brindan una plataforma armonizada y comparable internacionalmente que facilita análisis longitudinales rigurosos (World Bank Data Group, 2022).
# </div>
#
# ---
#
# <div class='subsection'>Marco Teórico</div>
#
# La teoría del capital humano (Becker, 1964; Mincer, 1974) establece que la inversión en educación eleva la productividad individual y agregada. Desde esta perspectiva, la no finalización de la educación primaria implica una pérdida irreversible de capital humano, con consecuencias negativas en el bienestar a lo largo del ciclo vital.
#
# El enfoque de capacidades (Sen, 1999; Nussbaum, 2000) complementa esta visión al señalar que la educación es condición necesaria para el ejercicio de libertades fundamentales: participación política, autonomía económica, salud reproductiva e integración social. En contextos de vulnerabilidad, las barreras al acceso escolar femenino —trabajo infantil, matrimonio precoz, falta de infraestructura— limitan el desarrollo de estas capacidades.
#
# Más recientemente, la literatura de *gender and development* (Kabeer, 2000; Duflo, 2012) documenta que la escolarización femenina genera externalidades positivas que van más allá del beneficio individual: reduce la mortalidad infantil, aumenta el ingreso familiar y fortalece la participación cívica. Estos hallazgos sustentan la inclusión de la tasa de finalización primaria femenina como indicador clave en los Objetivos de Desarrollo Sostenible (ODS 4: Educación de Calidad).
#
# ---
#
# <div class='subsection'>Hipótesis</div>
#
# <div class='callout-info'>
# <strong>H₁ (Tendencia temporal):</strong> La tasa de finalización primaria femenina global presenta una tendencia positiva durante el periodo 2000–2022, aunque con heterogeneidad regional significativa.<br><br>
# <strong>H₂ (No estacionariedad):</strong> La serie temporal de la mediana global de la tasa de finalización primaria femenina no es estrictamente estacionaria, lo que refleja una tendencia suave y persistente de mejora.<br><br>
# <strong>H₃ (Convergencia):</strong> La dispersión inter-país de la tasa se ha reducido a lo largo del periodo, indicando una convergencia hacia tasas más altas, aunque persisten países con rezagos estructurales pronunciados.
# </div>
#
# ---
#
# <div class='subsection'>Metodología</div>
#
# El análisis sigue un enfoque de **Análisis Exploratorio de Datos (EDA)** estructurado en tres etapas:
#
# **1. Obtención y procesamiento de datos.** Los datos se extraen de la API oficial del WDI mediante la librería `wbdata` de Python. El indicador central es `SE.PRM.CMPT.FE.ZS` para el periodo 2000–2022. Se aplican procedimientos de limpieza (eliminación de duplicados, corrección de tipos, división entre agrupaciones regionales y países individuales) y se genera una versión acotada de la variable en el rango [0, 100] para efectos de visualización.
#
# **2. Análisis de series de tiempo.** Previo al análisis univariado, se aplica la **prueba de Dickey-Fuller Aumentada (ADF)** sobre la serie anual de la mediana global para evaluar estacionariedad. Complementariamente, se calculan las funciones de **Autocorrelación (ACF)** y **Autocorrelación Parcial (PACF)** para caracterizar la estructura temporal de la serie.
#
# **3. Análisis univariado y bivariado.** Se examinan distribución, variabilidad y valores extremos de la variable principal. El análisis bivariado incorpora la dimensión temporal (evolución anual) y geográfica (mapa de calor por país), utilizando medidas robustas ante la asimetría del panel desbalanceado.
#
# ---
#
# <div class='subsection'>Objetivo del Análisis</div>
#
# Comprender el comportamiento de la tasa de finalización primaria femenina a nivel global mediante un EDA riguroso, que incluye la verificación de propiedades temporales (estacionariedad, autocorrelación), la descripción de su distribución y variabilidad, y la identificación de patrones geográficos y temporales relevantes para la formulación de políticas educativas.

# %%
# %pip install wbdata statsmodels

# %%
import wbdata
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# ── Paleta corporativa ──────────────────────────────────────────────────────
AZUL_OSCURO  = "#1a3c5e"
AZUL_MEDIO   = "#2d6a9f"
AZUL_CLARO   = "#4a9fd4"
AZUL_PASTEL  = "#b8d9f5"
VERDE        = "#27ae60"
NARANJA      = "#e6a817"
ROJO         = "#c0392b"
GRIS         = "#7f8c8d"

plt.rcParams.update({
    'figure.facecolor' : '#f7f4ee',
    'axes.facecolor'   : '#ffffff',
    'axes.edgecolor'   : '#cccccc',
    'axes.grid'        : True,
    'grid.alpha'       : 0.3,
    'grid.linestyle'   : '--',
    'font.family'      : 'DejaVu Sans',
    'axes.titlesize'   : 13,
    'axes.titleweight' : 'bold',
    'axes.labelsize'   : 11,
    'xtick.labelsize'  : 9,
    'ytick.labelsize'  : 9,
})

# ── Descarga de datos ───────────────────────────────────────────────────────
indicadores = {"SE.PRM.CMPT.FE.ZS": "female_completion"}
fecha_inicio = datetime.datetime(2000, 1, 1)
fecha_fin    = datetime.datetime(2022, 1, 1)

df = wbdata.get_dataframe(indicadores, date=(fecha_inicio, fecha_fin))
df = df.reset_index()
df.columns = ["pais", "anio", "tasa_fin"]
df = df.drop_duplicates()
df["anio"] = df["anio"].astype("Int64")

# ── División: regiones vs. países ──────────────────────────────────────────
df_1 = df.iloc[:1127]   # agrupaciones regionales
df_2 = df.iloc[1127:]   # países individuales

data = df_2.dropna(axis=0).copy()
data["tasa_fin_cap"] = data["tasa_fin"].clip(lower=0, upper=100)
data["anio"] = pd.to_numeric(data["anio"], errors="coerce")

print(f"Registros limpios (países): {len(data):,}")
print(f"Países únicos            : {data['pais'].nunique()}")
print(f"Rango temporal           : {int(data['anio'].min())}–{int(data['anio'].max())}")
data.head()

# %% [markdown]
# <div class='section-header'>2. Análisis de Series de Tiempo: ADF, ACF y PACF</div>
#
# <div class='callout-info'>
# Antes de describir la distribución de la variable, verificamos sus propiedades temporales. La <strong>prueba ADF</strong> evalúa si la serie tiene raíz unitaria (es no estacionaria). Las funciones <strong>ACF</strong> y <strong>PACF</strong> caracterizan la estructura de correlación serial, lo que orienta la selección de modelos de pronóstico y la interpretación de tendencias.
# </div>

# %%
# ── Serie anual (mediana global) ────────────────────────────────────────────
serie_anual = (
    data.groupby("anio")["tasa_fin_cap"]
    .median()
    .sort_index()
    .dropna()
)
anios = serie_anual.index.astype(int)

# ── Prueba ADF ──────────────────────────────────────────────────────────────
resultado_adf = adfuller(serie_anual, autolag='AIC')
estadistico_adf = resultado_adf[0]
p_valor         = resultado_adf[1]
vc              = resultado_adf[4]

print("=" * 52)
print("   PRUEBA DICKEY–FULLER AUMENTADA (ADF)")
print("=" * 52)
print(f"  Estadístico ADF  : {estadistico_adf:.4f}")
print(f"  p-value          : {p_valor:.4f}")
print(f"  Valores críticos :")
for k, v in vc.items():
    print(f"      {k}: {v:.4f}")
print("=" * 52)
if p_valor > 0.05:
    print("  → No se rechaza H₀ al 5%: la serie NO es estacionaria.")
    print("    Existe una tendencia temporal suave y persistente.")
else:
    print("  → Se rechaza H₀ al 5%: la serie ES estacionaria.")
print()

# ── Figura: Serie + ACF + PACF ─────────────────────────────────────────────
fig = plt.figure(figsize=(14, 10), facecolor='#f7f4ee')
fig.suptitle("Análisis de Series de Tiempo — Mediana anual de la tasa de finalización primaria femenina",
             fontsize=14, fontweight='bold', color=AZUL_OSCURO, y=1.01)

gs = gridspec.GridSpec(2, 2, figure=fig, hspace=0.45, wspace=0.35)

# Panel 1 — Serie temporal
ax1 = fig.add_subplot(gs[0, :])
ax1.plot(anios, serie_anual.values, color=AZUL_MEDIO, lw=2.5, marker='o',
         markersize=6, markerfacecolor='white', markeredgewidth=2, label='Mediana global')
ax1.fill_between(anios, serie_anual.values, serie_anual.min() - 0.5,
                 alpha=0.12, color=AZUL_MEDIO)

# Anotaciones ADF
txt = (f"ADF = {estadistico_adf:.3f}   p = {p_valor:.3f}\n"
       f"VC 5% = {vc['5%']:.3f}  →  Serie {'NO ' if p_valor > 0.05 else ''}estacionaria")
ax1.text(0.02, 0.07, txt, transform=ax1.transAxes,
         fontsize=9, color=ROJO if p_valor > 0.05 else VERDE,
         bbox=dict(facecolor='white', edgecolor=ROJO if p_valor>0.05 else VERDE,
                   boxstyle='round,pad=0.4', alpha=0.85))

ax1.set_title("Serie temporal: Mediana global de finalización primaria", fontsize=12)
ax1.set_xlabel("Año"); ax1.set_ylabel("tasa_fin_cap (%)")
ax1.set_xticks(anios); ax1.tick_params(axis='x', rotation=45)
ax1.legend(fontsize=9)

# Panel 2 — ACF
ax2 = fig.add_subplot(gs[1, 0])
nlags = min(10, len(serie_anual) // 2 - 1)
plot_acf(serie_anual, lags=nlags, ax=ax2, color=AZUL_MEDIO,
         title='ACF — Función de Autocorrelación', zero=False)
ax2.set_xlabel("Rezago"); ax2.set_ylabel("Autocorrelación")
ax2.axhline(0, color='black', lw=0.8)

# Panel 3 — PACF
ax3 = fig.add_subplot(gs[1, 1])
plot_pacf(serie_anual, lags=nlags, ax=ax3, color=AZUL_MEDIO,
          title='PACF — Autocorrelación Parcial', zero=False, method='ywm')
ax3.set_xlabel("Rezago"); ax3.set_ylabel("Autocorrelación parcial")
ax3.axhline(0, color='black', lw=0.8)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class='callout-result'>
# <strong>Interpretación:</strong><br>
# • <strong>ADF:</strong> El estadístico ADF = −2.82 (p = 0.055) no supera el umbral del 5%, lo que indica que <em>no se rechaza la hipótesis nula de raíz unitaria</em>. La serie presenta una tendencia temporal suave y persistente al alza, confirmando la H₂.<br><br>
# • <strong>ACF:</strong> Las autocorrelaciones decaen lentamente hacia cero a medida que aumentan los rezagos. Este patrón de decaimiento gradual es característico de series con tendencia (no estacionarias), donde los valores pasados siguen siendo informativos varios períodos después.<br><br>
# • <strong>PACF:</strong> La autocorrelación parcial es significativa solo en el rezago 1 (y ocasionalmente en el 2), mientras que los siguientes quedan dentro de las bandas de confianza. Esto sugiere que, una vez removida la tendencia, la estructura subyacente sería compatible con un proceso AR(1) o AR(2).
# </div>
#
# <div class='callout-warn'>
# <strong>Implicación metodológica:</strong> Dado que la serie no es estacionaria, las comparaciones directas entre años deben interpretarse como cambios <em>dentro</em> de una tendencia ascendente. Para modelado predictivo formal sería necesario diferenciar la serie o incluir una tendencia explícita.
# </div>

# %% [markdown]
# <div class='section-header'>3. Análisis Univariado</div>
#
# <div class='callout-info'>
# Describimos cada variable por separado antes de realizar comparaciones. Trabajamos con <code>tasa_fin_cap ∈ [0, 100]</code> para las visualizaciones, conservando la variable original para trazabilidad. El dataset es un <em>panel desbalanceado</em>: no todos los países reportan datos en todos los años.
# </div>

# %%
desc = data["tasa_fin_cap"].describe()
print("Estadísticas descriptivas — tasa_fin_cap (%)")
print(desc.to_string())
print("\nPercentiles adicionales:")
print(data["tasa_fin_cap"].quantile([0.01, 0.10, 0.25, 0.50, 0.75, 0.90, 0.99]).to_string())
print(f"\nCoeficiente de asimetría : {data['tasa_fin_cap'].skew():.3f}")
print(f"Kurtosis                 : {data['tasa_fin_cap'].kurt():.3f}")

# ── Figura: histograma + boxplot + distribución de años ───────────────────
fig, axes = plt.subplots(1, 3, figsize=(16, 5), facecolor='#f7f4ee')
fig.suptitle("Análisis Univariado — Tasa de finalización primaria femenina",
             fontsize=14, fontweight='bold', color=AZUL_OSCURO)

# --- Histograma con KDE
ax = axes[0]
sns.histplot(data["tasa_fin_cap"], bins=np.arange(0, 105, 5),
             kde=True, color=AZUL_MEDIO, alpha=0.65, ax=ax,
             line_kws={'color': AZUL_OSCURO, 'lw': 2})
ax.axvline(desc['mean'], color=NARANJA, lw=1.8, ls='--', label=f"Media {desc['mean']:.1f}%")
ax.axvline(desc['50%'],  color=ROJO,    lw=1.8, ls='-',  label=f"Mediana {desc['50%']:.1f}%")
ax.set_title("Distribución de tasa_fin_cap")
ax.set_xlabel("tasa_fin_cap (%)"); ax.set_ylabel("Frecuencia")
ax.set_xlim(0, 100); ax.legend(fontsize=8)

# --- Boxplot
ax = axes[1]
bp = ax.boxplot(data["tasa_fin_cap"].dropna(), vert=True, patch_artist=True,
                boxprops=dict(facecolor=AZUL_PASTEL, color=AZUL_OSCURO),
                medianprops=dict(color=ROJO, lw=2.5),
                whiskerprops=dict(color=AZUL_MEDIO),
                capprops=dict(color=AZUL_MEDIO),
                flierprops=dict(marker='o', markerfacecolor=NARANJA,
                                markersize=4, alpha=0.4))
ax.set_title("Boxplot de tasa_fin_cap")
ax.set_ylabel("tasa_fin_cap (%)"); ax.set_ylim(0, 100)
ax.set_xticks([])
# Anotaciones cuartiles
for q, label in zip([desc['25%'], desc['50%'], desc['75%']], ['Q1', 'Q2', 'Q3']):
    ax.annotate(f"{label}={q:.1f}%", xy=(1, q), xytext=(1.12, q),
                fontsize=8, color=AZUL_OSCURO,
                arrowprops=dict(arrowstyle='-', color=GRIS, lw=0.8))

# --- Distribución de años
ax = axes[2]
conteo_anio = data.groupby("anio")["pais"].nunique().reset_index()
conteo_anio.columns = ["anio", "n_paises"]
ax.bar(conteo_anio["anio"], conteo_anio["n_paises"],
       color=AZUL_CLARO, edgecolor=AZUL_OSCURO, linewidth=0.6)
ax.set_title("Países con dato por año")
ax.set_xlabel("Año"); ax.set_ylabel("N° de países")
ax.set_xticks(conteo_anio["anio"][::3]); ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

print(f"\nPaíses únicos con al menos un dato : {data['pais'].nunique()}")

# %% [markdown]
# <div class='section-header'>4. Análisis Bivariado</div>
#
# <div class='callout-info'>
# Exploramos la relación entre la tasa de finalización y la dimensión temporal, geográfica y de cobertura. Usamos <code>tasa_fin_cap ∈ [0, 100]</code> para comparabilidad visual y reportamos el número efectivo de observaciones en cada contraste.
# </div>

# %%
objetivo_anios = list(range(2000, 2023))
n_anios = len(objetivo_anios)

df_win = data[data["anio"].isin(objetivo_anios)].copy()

cob = (
    df_win[["pais", "anio"]].drop_duplicates()
    .groupby("pais").size()
    .reset_index(name="n_anios")
)
cob["frac"] = cob["n_anios"] / n_anios

n_paises    = cob["pais"].nunique()
n_completos = (cob["n_anios"] == n_anios).sum()
pct_comp    = n_completos / n_paises * 100

print(f"Países con ≥1 dato (2000–2022) : {n_paises}")
print(f"Países con cobertura completa  : {n_completos} ({pct_comp:.1f}%)")
print(f"Mediana de años reportados     : {cob['n_anios'].median():.0f}")
print(f"Mínimo / Máximo de años        : {cob['n_anios'].min()} / {cob['n_anios'].max()}")

# ── Histograma de cobertura ────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(9, 4), facecolor='#f7f4ee')
ax.hist(cob["n_anios"], bins=range(1, n_anios + 2), color=AZUL_MEDIO,
        edgecolor=AZUL_OSCURO, linewidth=0.6, rwidth=0.85)
ax.axvline(n_anios, color=ROJO, lw=2, ls='--', label=f"Cobertura completa ({n_anios} años)")
ax.set_title("Distribución de cobertura temporal por país (2000–2022)",
             fontsize=12, fontweight='bold', color=AZUL_OSCURO)
ax.set_xlabel("Número de años con dato disponible")
ax.set_ylabel("Número de países")
ax.legend(fontsize=9)
plt.tight_layout()
plt.show()

# %%
# ── Países con cobertura completa ──────────────────────────────────────────
paises_completos = cob[cob["n_anios"] == n_anios]["pais"]
df_top = data[data["pais"].isin(paises_completos)].copy()

trend = df_top.groupby("anio")["tasa_fin_cap"].agg(['median','mean','std']).reset_index()
trend.columns = ["anio", "mediana", "media", "std"]

fig, axes = plt.subplots(1, 2, figsize=(14, 5), facecolor='#f7f4ee')
fig.suptitle("Evolución temporal — Países con cobertura completa (n=30)",
             fontsize=13, fontweight='bold', color=AZUL_OSCURO)

# --- Mediana + banda
ax = axes[0]
ax.plot(trend["anio"], trend["mediana"], color=AZUL_MEDIO, lw=2.5,
        marker='o', markersize=5, markerfacecolor='white', markeredgewidth=2,
        label='Mediana')
ax.plot(trend["anio"], trend["media"], color=NARANJA, lw=1.8, ls='--', label='Media')
ax.fill_between(trend["anio"],
                trend["mediana"] - trend["std"],
                trend["mediana"] + trend["std"],
                alpha=0.12, color=AZUL_MEDIO, label='±1 std')
ax.set_title("Mediana y media anuales"); ax.set_xlabel("Año")
ax.set_ylabel("tasa_fin_cap (%)"); ax.legend(fontsize=9)
ax.set_xticks(trend["anio"][::3]); ax.tick_params(axis='x', rotation=45)

# --- Boxplots por año
ax = axes[1]
bp_data = [df_top[df_top["anio"]==y]["tasa_fin_cap"].dropna().values
           for y in sorted(df_top["anio"].unique())]
years_sorted = sorted(df_top["anio"].unique())
bp = ax.boxplot(bp_data, patch_artist=True,
                boxprops=dict(facecolor=AZUL_PASTEL, color=AZUL_OSCURO),
                medianprops=dict(color=ROJO, lw=2),
                whiskerprops=dict(color=AZUL_MEDIO),
                capprops=dict(color=AZUL_MEDIO),
                flierprops=dict(marker='o', markerfacecolor=NARANJA,
                                markersize=3, alpha=0.5))
ax.set_title("Distribución por año (boxplots)")
ax.set_xlabel("Año"); ax.set_ylabel("tasa_fin_cap (%)")
ax.set_xticks(range(1, len(years_sorted)+1, 3))
ax.set_xticklabels([str(y) for y in years_sorted[::3]], rotation=45)
ax.set_ylim(0, 100)

plt.tight_layout()
plt.show()

# %%
try:
    import plotly.express as px
    map_data = df_top.groupby("pais")["tasa_fin_cap"].median().reset_index()
    fig = px.choropleth(
        map_data,
        locations="pais",
        locationmode="country names",
        color="tasa_fin_cap",
        color_continuous_scale="Blues",
        range_color=(0, 100),
        title="Mediana de la tasa de finalización primaria por país (2000–2022)",
    )
    fig.update_layout(coloraxis_colorbar=dict(title="tasa_fin_cap (%)"))
    fig.show()
except ImportError:
    print("Plotly no disponible. Omitiendo mapa coroplético.")

# %%
n_mayor_100  = (data["tasa_fin"] > 100).sum()
pct_mayor    = (data["tasa_fin"] > 100).mean() * 100
max_tasa     = data["tasa_fin"].max()

print(f"Observaciones > 100%  : {n_mayor_100}  ({pct_mayor:.1f}% del total)")
print(f"Valor máximo observado: {max_tasa:.2f}%")
print()

top15 = (
    data[data["tasa_fin"] > 100]
    .sort_values("tasa_fin", ascending=False)
    [["pais", "anio", "tasa_fin"]]
    .head(15)
    .reset_index(drop=True)
)
print("Top-15 observaciones con tasa_fin > 100%:")
print(top15.to_string(index=False))

# ── Visualización outliers ─────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(10, 5), facecolor='#f7f4ee')
colores  = [NARANJA if v > 100 else AZUL_MEDIO for v in top15["tasa_fin"]]
etiquetas = [f"{row['pais']} ({int(row['anio'])})" for _, row in top15.iterrows()]
barras = ax.barh(range(len(top15)), top15["tasa_fin"], color=colores,
                 edgecolor=AZUL_OSCURO, linewidth=0.5)
ax.axvline(100, color=ROJO, lw=2, ls='--', label='100% (umbral lógico)')
ax.set_yticks(range(len(top15))); ax.set_yticklabels(etiquetas, fontsize=9)
ax.set_xlabel("tasa_fin (%)")
ax.set_title("Top 15 observaciones con tasa_fin > 100%",
             fontsize=12, fontweight='bold', color=AZUL_OSCURO)
ax.legend(fontsize=9)
ax.invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class='section-header'>5. Conclusiones</div>
#
# <div class='callout-result'>
#
# Este análisis exploratorio de la tasa de finalización de la educación primaria femenina a nivel global (2000–2022), basado en datos del World Development Indicators del Banco Mundial, permite extraer las siguientes conclusiones:
#
# ---
#
# **1. Tendencia positiva global, aunque no estacionaria (H₁ ✓ — H₂ ✓)**
#
# La prueba de Dickey-Fuller Aumentada confirmó que la mediana anual de la tasa de finalización primaria femenina no es estacionaria (ADF = −2.82; p = 0.055). Esto refleja una tendencia temporal suave y persistente al alza: la mediana global pasó de aproximadamente 90% en el año 2000 a valores cercanos al 97–98% en 2020–2022. Esta mejora es estadísticamente distinguible de fluctuaciones aleatorias, lo que valida las hipótesis H₁ y H₂.
#
# Las funciones ACF y PACF refuerzan este diagnóstico: las autocorrelaciones decaen lentamente (indicando estructura temporal persistente) y la PACF sugiere que la dependencia fundamental se concentra en los primeros 1–2 rezagos, característica de un proceso autorregresivo de orden bajo.
#
# ---
#
# **2. Convergencia inter-país hacia tasas más altas (H₃ ✓)**
#
# El análisis por año revela que el rango intercuartílico se ha reducido progresivamente: en 2000–2005, la dispersión entre países era considerable, mientras que en 2018–2022 las cajas son notablemente más estrechas. Este patrón de convergencia confirma la hipótesis H₃: los países han tendido a acercarse hacia tasas más homogéneas y elevadas de finalización primaria femenina.
#
# ---
#
# **3. Persistencia de rezagos estructurales**
#
# A pesar de la mejora generalizada, subsisten valores atípicos por debajo del resto en todos los años del periodo. Los países con las tasas más bajas (en algunos años por debajo del 30%) representan contextos marcados por conflictos armados, pobreza extrema o barreras culturales profundas que ninguna tendencia agregada puede suavizar. El mínimo global ha mejorado (de ~10–15% en 2000 a ~30–40% en 2020), lo que es alentador, pero insuficiente desde la perspectiva de los derechos humanos y los ODS.
#
# ---
#
# **4. Valores superiores al 100% y calidad de los datos**
#
# Un 25% de las observaciones originales superan el 100%, lo que obedece a la metodología de cálculo del indicador WDI: el numerador incluye a todos los egresados de primaria sin importar la edad, mientras el denominador corresponde solo a la cohorte oficial. Esta característica no implica error en los datos, sino un fenómeno demográfico (estudiantes en sobredad o subedad). Para el análisis visual se utilizó la versión acotada [0, 100], pero los valores originales se conservan para trazabilidad.
#
# ---
#
# **5. Limitaciones y extensiones**
#
# El panel es desbalanceado: solo 30 de 192 países (15.6%) reportan datos en todos los 23 años analizados. Esto impone cautela en las comparaciones directas y recomienda el uso de métodos robustos ante la ausencia de datos. Extensiones naturales de este análisis incluyen: (i) modelos de datos de panel con efectos fijos por país; (ii) análisis de brechas de género comparando la tasa masculina; y (iii) modelos de pronóstico ARIMA o ETS para proyectar el indicador hacia 2030 en el contexto de los ODS.
#
# </div>
#
# ---
#
# <div class='section-header'>6. Referencias</div>
#
# <div class='ref-item'><span>Becker, G. S. (1964).</span> <em>Human Capital: A Theoretical and Empirical Analysis, with Special Reference to Education.</em> National Bureau of Economic Research.</div>
# <div class='ref-item'><span>Duflo, E. (2012).</span> Women Empowerment and Economic Development. <em>Journal of Economic Literature, 50</em>(4), 1051–1079.</div>
# <div class='ref-item'><span>Kabeer, N. (2000).</span> <em>The Power to Choose: Bangladeshi Women and Labour Market Decisions in London and Dhaka.</em> Verso Books.</div>
# <div class='ref-item'><span>Mincer, J. (1974).</span> <em>Schooling, Experience, and Earnings.</em> National Bureau of Economic Research.</div>
# <div class='ref-item'><span>Nussbaum, M. (2000).</span> <em>Women and Human Development: The Capabilities Approach.</em> Cambridge University Press.</div>
# <div class='ref-item'><span>Sen, A. (1999).</span> <em>Development as Freedom.</em> Oxford University Press.</div>
# <div class='ref-item'><span>UNESCO. (2021).</span> <em>Global Education Monitoring Report 2021/2: Non-State Actors in Education.</em> UNESCO Publishing.</div>
# <div class='ref-item'><span>UNICEF. (2022).</span> <em>The State of the World's Children 2022.</em> UNICEF.</div>
# <div class='ref-item'><span>World Bank. (2023).</span> <em>World Development Report 2023: Migrants, Refugees, and Societies.</em> World Bank Group.</div>
# <div class='ref-item'><span>World Bank Data Group. (2022).</span> <em>World Development Indicators.</em> Recuperado de https://data.worldbank.org/indicator/SE.PRM.CMPT.FE.ZS</div>
